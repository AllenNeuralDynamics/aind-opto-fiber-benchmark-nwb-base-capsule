# %%
from hdmf_zarr import NWBZarrIO

# %%
with NWBZarrIO("/root/capsule/results/FIP_790912_2025-07-11_14-41-59.nwb", mode="r") as io:
    nwb = io.read()

# %%
events = nwb.get_events__events_tables().to_dataframe()

# %%
events
# Out:
#        timestamp                 event
# id
# 0   5.305048e+07   OptoStimLaser_onset
# 1   5.305248e+07  OptoStimLaser_offset
# 2   5.308048e+07   OptoStimLaser_onset
# 3   5.308248e+07  OptoStimLaser_offset
# 4   5.311049e+07   OptoStimLaser_onset
# ..           ...                   ...
# 75  5.416261e+07  OptoStimLaser_offset
# 76  5.419062e+07   OptoStimLaser_onset
# 77  5.419262e+07  OptoStimLaser_offset
# 78  5.422062e+07   OptoStimLaser_onset
# 79  5.422262e+07  OptoStimLaser_offset
#
# [80 rows x 2 columns]
