# %%
from hdmf_zarr import NWBZarrIO

# %%
with NWBZarrIO('/root/capsule/results/behavior_789919_2025-09-17_19-30-21.nwb.zarr', mode='r') as io:
    nwb = io.read()

# %%
events = nwb.get_events__events_tables()
event_table_df = events.to_dataframe()
event_meanings_table = events.meanings_tables["meanings"][:]

# %%
event_table_df
# Out:
#        timestamp                 event
# id
# 0   6.425597e+07   OptoStimLaser_onset
# 1   6.425797e+07  OptoStimLaser_offset
# 2   6.428597e+07   OptoStimLaser_onset
# 3   6.428797e+07  OptoStimLaser_offset
# 4   6.431598e+07   OptoStimLaser_onset
# 5   6.431798e+07  OptoStimLaser_offset
# 6   6.434598e+07   OptoStimLaser_onset
# 7   6.434798e+07  OptoStimLaser_offset
# 8   6.437598e+07   OptoStimLaser_onset
# 9   6.437798e+07  OptoStimLaser_offset
# 10  6.440599e+07   OptoStimLaser_onset
# 11  6.440799e+07  OptoStimLaser_offset
# 12  6.443599e+07   OptoStimLaser_onset
# 13  6.443799e+07  OptoStimLaser_offset
# 14  6.446599e+07   OptoStimLaser_onset
# 15  6.446799e+07  OptoStimLaser_offset
# 16  6.449600e+07   OptoStimLaser_onset
# 17  6.449800e+07  OptoStimLaser_offset
# 18  6.452600e+07   OptoStimLaser_onset
# 19  6.452800e+07  OptoStimLaser_offset

# %%
event_meanings_table
# Out:
#                    value                               meaning  \
# id
# 0    OptoStimLaser_onset   Onset of Optogenetic Stimulus Laser
# 1   OptoStimLaser_offset  Offset of Optogenetic Stimulus Laser
#
#                          HED_tag
# id
# 0    Onset/Experimental-stimulus
# 1   Offset/Experimental-stimulus
